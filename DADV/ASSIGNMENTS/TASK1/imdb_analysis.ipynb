# %% [markdown]
# # Find the average rank of the 10 most popular movies between 2000-2009 (inclusive)

# %%
import pandas as pd
import numpy as np

# %%
ratings = pd.read_csv("/Users/pemawangmo/Desktop/DS_Notes/DADV/assignments/IMDB/data/titleRatings.tsv", delimiter = '\t')

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1668
# 1  tt0000002            6.1       207
# 2  tt0000003            6.5      1389
# 3  tt0000004            6.2       123
# 4  tt0000005            6.2      2177

# %%
basics_movie = pd.read_csv("/Users/pemawangmo/Desktop/DS_Notes/DADV/assignments/IMDB/data/titleBasics.tsv", delimiter = '\t')
# Out:
# /Users/pemawangmo/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
basics_movie.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1              Comedy,Short

# %%
basics_movie.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult            int64
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
basics_movie['startYear'] = pd.to_numeric(basics_movie['startYear'], errors='coerce')

# %%
basics_movie.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult             int64
# startYear         float64
# endYear            object
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
year = basics_movie[(basics_movie.startYear >= 2000) & (basics_movie.startYear <= 2009)]
year
# Out:
#             tconst  titleType                primaryTitle  \
# 15184    tt0015414      movie      La tierra de los toros
# 18037    tt0018295      short           El puño de hierro
# 33811    tt0034413      short          Youth Gets a Break
# 34811    tt0035423      movie              Kate & Leopold
# 63462    tt0064730      movie  Japan Organized Crime Boss
# ...            ...        ...                         ...
# 7451413  tt9916794  tvEpisode               Episode #2.33
# 7451414  tt9916796  tvEpisode               Episode #2.34
# 7451415  tt9916798  tvEpisode               Episode #2.36
# 7451416  tt9916800  tvEpisode               Episode #2.35
# 7451418  tt9916804  tvEpisode               Episode #2.37
#
#                       originalTitle  isAdult  startYear endYear  \
# 15184        La tierra de los toros        0     2000.0      \N
# 18037             El puño de hierro        0     2004.0      \N
# 33811            Youth Gets a Break        0     2001.0      \N
# 34811                Kate & Leopold        0     2001.0      \N
# 63462    Nihon boryoku-dan: Kumicho        0     2000.0      \N
# ...                             ...      ...        ...     ...
# 7451413               Episode #2.33        0     2009.0      \N
# 7451414               Episode #2.34        0     2009.0      \N
# 7451415               Episode #2.36        0     2009.0      \N
# 7451416               Episode #2.35        0     2009.0      \N
# 7451418               Episode #2.37        0     2009.0      \N
#
#         runtimeMinutes                  genres
# 15184               60                      \N
# 18037               40      Action,Drama,Short
# 33811               20                   Short
# 34811              118  Comedy,Fantasy,Romance
# 63462               97            Action,Crime
# ...                ...                     ...
# 7451413             \N     Action,Drama,Family
# 7451414             \N     Action,Drama,Family
# 7451415             \N     Action,Drama,Family
# 7451416             \N     Action,Drama,Family
# 7451418             \N     Action,Drama,Family
#
# [1402625 rows x 9 columns]

# %%
year_rating_merged = pd.merge(year, ratings, on='tconst')
year_rating_merged.head()
# Out:
#       tconst titleType                primaryTitle  \
# 0  tt0015414     movie      La tierra de los toros
# 1  tt0018295     short           El puño de hierro
# 2  tt0035423     movie              Kate & Leopold
# 3  tt0064730     movie  Japan Organized Crime Boss
# 4  tt0087608     movie            Leila wa al ziap
#
#                 originalTitle  isAdult  startYear endYear runtimeMinutes  \
# 0      La tierra de los toros        0     2000.0      \N             60
# 1           El puño de hierro        0     2004.0      \N             40
# 2              Kate & Leopold        0     2001.0      \N            118
# 3  Nihon boryoku-dan: Kumicho        0     2000.0      \N             97
# 4            Leila wa al ziap        0     2008.0      \N             90
#
#                    genres  averageRating  numVotes
# 0                      \N            5.4        11
# 1      Action,Drama,Short            6.7        30
# 2  Comedy,Fantasy,Romance            6.4     78627
# 3            Action,Crime            7.0       172
# 4             Documentary            7.7        13

# %%
only_movies = year_rating_merged.loc[year_rating_merged['titleType'] == 'movie']
only_movies
# Out:
#            tconst titleType                            primaryTitle  \
# 0       tt0015414     movie                  La tierra de los toros
# 2       tt0035423     movie                          Kate & Leopold
# 3       tt0064730     movie              Japan Organized Crime Boss
# 4       tt0087608     movie                        Leila wa al ziap
# 5       tt0088751     movie                       The Naked Monster
# ...           ...       ...                                     ...
# 251595  tt9856558     movie  Magnus Lindberg - den siste rockpoeten
# 251611  tt9874290     movie           Star Trek: Incident at Beta 9
# 251612  tt9876412     movie           Star Trek: The Final Darkness
# 251625  tt9881364     movie                                    Gaja
# 251648  tt9900614     movie                               Lady Boss
#
#                                  originalTitle  isAdult  startYear endYear  \
# 0                       La tierra de los toros        0     2000.0      \N
# 2                               Kate & Leopold        0     2001.0      \N
# 3                   Nihon boryoku-dan: Kumicho        0     2000.0      \N
# 4                             Leila wa al ziap        0     2008.0      \N
# 5                            The Naked Monster        0     2005.0      \N
# ...                                        ...      ...        ...     ...
# 251595  Magnus Lindberg - den siste rockpoeten        0     2005.0      \N
# 251611           Star Trek: Incident at Beta 9        0     2002.0      \N
# 251612           Star Trek: The Final Darkness        0     2004.0      \N
# 251625                                    Gaja        0     2008.0      \N
# 251648                               Lady Boss        0     2005.0      \N
#
#        runtimeMinutes                  genres  averageRating  numVotes
# 0                  60                      \N            5.4        11
# 2                 118  Comedy,Fantasy,Romance            6.4     78627
# 3                  97            Action,Crime            7.0       172
# 4                  90             Documentary            7.7        13
# 5                 100    Comedy,Horror,Sci-Fi            5.4       273
# ...               ...                     ...            ...       ...
# 251595             59               Biography            1.0         5
# 251611             57                  Sci-Fi            5.0         5
# 251612             85                  Sci-Fi            4.4         5
# 251625             \N   Action,Comedy,Romance            7.3        24
# 251648             \N                  Comedy            5.2        17
#
# [45537 rows x 11 columns]

# %%
popular_movie = only_movies.sort_values('numVotes', ascending = False)

# %%
print(popular_movie.head(10)['averageRating'].mean())
# Out:
# 8.580000000000002

# %% [markdown]
# # Find the year in the 1900s when the average rank increased the most, compared to the previous year.(Ignore movies with votes < 1000)

# %%
votes = ratings[ratings['numVotes'] > 1000]
votes
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.6      1668
# 2        tt0000003            6.5      1389
# 4        tt0000005            6.2      2177
# 7        tt0000008            5.4      1840
# 9        tt0000010            6.9      6137
# ...            ...            ...       ...
# 1104420  tt9900782            8.5     10761
# 1104505  tt9904802            4.8      1084
# 1104551  tt9906260            9.9     32869
# 1104605  tt9908860            6.9      1518
# 1104690  tt9911196            7.7      1004
#
# [59127 rows x 3 columns]

# %%
votes_merged = pd.merge(votes, basics_movie, on = 'tconst')

# %%
year = votes_merged[(votes_merged['startYear'] >= 1900) & (votes_merged['startYear'] < 2000)]

# %%
year_output = year.groupby('startYear').agg(avgR = ('averageRating', np.mean)).reset_index()

# %%
flag = 0
final_yr = 0
for i in range(1, len(year_output)):
    a = year_output.loc[i, 'avgR']
    b = year_output.loc[i-1, 'avgR']
    temp = abs(a - b)
    if temp > flag:
        flag = temp
        final_yr = year_output.loc[[i], ['startYear']]
final_yr
# Out:
#    startYear
# 3     1903.0

# %% [markdown]
# # Find the expected average rank for 2013 using linear regression. How good is this regression? (Ignore movies with votes < 1000.)

# %%
rating_merged = pd.merge(ratings, basics_movie, on = 'tconst')
rating_merged
# Out:
#             tconst  averageRating  numVotes  titleType  \
# 0        tt0000001            5.6      1668      short
# 1        tt0000002            6.1       207      short
# 2        tt0000003            6.5      1389      short
# 3        tt0000004            6.2       123      short
# 4        tt0000005            6.2      2177      short
# ...            ...            ...       ...        ...
# 1104892  tt9916580            7.2         5  tvEpisode
# 1104893  tt9916690            6.6         5  tvEpisode
# 1104894  tt9916720            6.1        68      short
# 1104895  tt9916766            6.9        15  tvEpisode
# 1104896  tt9916778            7.4        25  tvEpisode
#
#                            primaryTitle                   originalTitle  \
# 0                            Carmencita                      Carmencita
# 1                Le clown et ses chiens          Le clown et ses chiens
# 2                        Pauvre Pierrot                  Pauvre Pierrot
# 3                           Un bon bock                     Un bon bock
# 4                      Blacksmith Scene                Blacksmith Scene
# ...                                 ...                             ...
# 1104892        Horrid Henry Horrid Boy?        Horrid Henry Horrid Boy?
# 1104893  Horrid Henry Delivers the Milk  Horrid Henry Delivers the Milk
# 1104894                       The Nun 2                       The Nun 2
# 1104895                  Episode #10.15                  Episode #10.15
# 1104896                          Escape                          Escape
#
#          isAdult  startYear endYear runtimeMinutes                    genres
# 0              0     1894.0      \N              1         Documentary,Short
# 1              0     1892.0      \N              5           Animation,Short
# 2              0     1892.0      \N              4  Animation,Comedy,Romance
# 3              0     1892.0      \N             12           Animation,Short
# 4              0     1893.0      \N              1              Comedy,Short
# ...          ...        ...     ...            ...                       ...
# 1104892        0     2012.0      \N             10   Animation,Comedy,Family
# 1104893        0     2012.0      \N             \N   Animation,Comedy,Family
# 1104894        0     2019.0      \N             10     Comedy,Horror,Mystery
# 1104895        0     2019.0      \N             43         Family,Reality-TV
# 1104896        0     2019.0      \N             \N                     Drama
#
# [1104897 rows x 11 columns]

# %%
vote = rating_merged[rating_merged['numVotes']>= 1000]
vote
# Out:
#             tconst  averageRating  numVotes  titleType  \
# 0        tt0000001            5.6      1668      short
# 2        tt0000003            6.5      1389      short
# 4        tt0000005            6.2      2177      short
# 7        tt0000008            5.4      1840      short
# 9        tt0000010            6.9      6137      short
# ...            ...            ...       ...        ...
# 1104420  tt9900782            8.5     10761      movie
# 1104505  tt9904802            4.8      1084      movie
# 1104551  tt9906260            9.9     32869  tvEpisode
# 1104605  tt9908860            6.9      1518   tvSeries
# 1104690  tt9911196            7.7      1004      movie
#
#                                    primaryTitle  \
# 0                                    Carmencita
# 2                                Pauvre Pierrot
# 4                              Blacksmith Scene
# 7        Edison Kinetoscopic Record of a Sneeze
# 9                           Leaving the Factory
# ...                                         ...
# 1104420                                  Kaithi
# 1104505                             Enemy Lines
# 1104551                                    Hero
# 1104605                              Blown Away
# 1104690                     The Marriage Escape
#
#                                   originalTitle  isAdult  startYear endYear  \
# 0                                    Carmencita        0     1894.0      \N
# 2                                Pauvre Pierrot        0     1892.0      \N
# 4                              Blacksmith Scene        0     1893.0      \N
# 7        Edison Kinetoscopic Record of a Sneeze        0     1894.0      \N
# 9           La sortie de l'usine Lumière à Lyon        0     1895.0      \N
# ...                                         ...      ...        ...     ...
# 1104420                                  Kaithi        0     2019.0      \N
# 1104505                             Enemy Lines        0     2020.0      \N
# 1104551                                    Hero        0     2019.0      \N
# 1104605                              Blown Away        0     2019.0      \N
# 1104690          De beentjes van Sint-Hildegard        0     2020.0      \N
#
#         runtimeMinutes                      genres
# 0                    1           Documentary,Short
# 2                    4    Animation,Comedy,Romance
# 4                    1                Comedy,Short
# 7                    1           Documentary,Short
# 9                    1           Documentary,Short
# ...                ...                         ...
# 1104420            145             Action,Thriller
# 1104505             92                         War
# 1104551             24  Action,Adventure,Animation
# 1104605             23                  Reality-TV
# 1104690            103                Comedy,Drama
#
# [59159 rows x 11 columns]

# %%
vote_output = vote.groupby('startYear').agg(avgR = ('averageRating', np.mean)).reset_index()

# %%
vote_output
# Out:
#      startYear      avgR
# 0       1874.0  6.900000
# 1       1878.0  7.400000
# 2       1887.0  5.200000
# 3       1888.0  6.500000
# 4       1890.0  5.000000
# ..         ...       ...
# 130     2016.0  7.164725
# 131     2017.0  7.182420
# 132     2018.0  7.135489
# 133     2019.0  7.214563
# 134     2020.0  7.143500
#
# [135 rows x 2 columns]

# %%
vote_output = vote_output[vote_output.startYear != 2013]
vote_output
# Out:
#      startYear      avgR
# 0       1874.0  6.900000
# 1       1878.0  7.400000
# 2       1887.0  5.200000
# 3       1888.0  6.500000
# 4       1890.0  5.000000
# ..         ...       ...
# 130     2016.0  7.164725
# 131     2017.0  7.182420
# 132     2018.0  7.135489
# 133     2019.0  7.214563
# 134     2020.0  7.143500
#
# [134 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train = vote_output['startYear'].values.reshape(-1,1)
y_train = vote_output['avgR'].values.reshape(-1,1)

# %%
model = LinearRegression().fit(x_train,y_train)

# %%
xtest = np.array([2013]).reshape(-1,1)
prediction = model.predict(xtest)
print(prediction)
# Out:
# [[7.00533832]]

# %%
# To visualize
import matplotlib.pyplot as plt

# %%
temp_pred = model.predict(x_train)
plt.scatter(x_train, y_train)
plt.plot(x_train, temp_pred, color='red')
plt.show()

# %% [markdown]
# # Find the correlation between rank and votes for each year in the 1900s. By how much did the correlation coefficient grow each year? How good is this regression?

# %%
corrl_year = basics_movie[(basics_movie['startYear']>= 1900) & (basics_movie['startYear'] < 2000)]

# %%
corrl_Data = pd.merge(ratings, corrl_year, on='tconst')
corrl_Data
# Out:
#            tconst  averageRating  numVotes  titleType  \
# 0       tt0000160            5.2         9      short
# 1       tt0000265            4.3       100      short
# 2       tt0000269            4.9       100      short
# 3       tt0000271            6.4         7      short
# 4       tt0000272            5.6       689      short
# ...           ...            ...       ...        ...
# 363793  tt9909834            7.2         6      video
# 363794  tt9909866            4.4         8      video
# 363795  tt9914702            6.8        13  tvEpisode
# 363796  tt9915946            6.2         6      movie
# 363797  tt9916220            6.7        10  tvEpisode
#
#                                              primaryTitle  \
# 0                                The Last Days of Pompeii
# 1                                         Above the Limit
# 2       Army Life; or, How Soldiers Are Made: Mounted ...
# 3                          Arrivée de Pierette et Pierrot
# 4                             As Seen Through a Telescope
# ...                                                   ...
# 363793                  Alice Cooper: Love's a Loaded Gun
# 363794                                               Nora
# 363795                      Episode dated 5 February 1988
# 363796                                   Nuestra película
# 363797                          Episode dated 18 May 1988
#
#                             originalTitle  isAdult  startYear endYear  \
# 0                The Last Days of Pompeii        0     1900.0      \N
# 1                         Above the Limit        0     1900.0      \N
# 2                               Army Life        0     1900.0      \N
# 3          Arrivée de Pierette et Pierrot        0     1900.0      \N
# 4             As Seen Through a Telescope        0     1900.0      \N
# ...                                   ...      ...        ...     ...
# 363793  Alice Cooper: Love's a Loaded Gun        0     1991.0      \N
# 363794                               Nora        0     1985.0      \N
# 363795      Episode dated 5 February 1988        0     1988.0      \N
# 363796                   Nuestra película        0     1993.0      \N
# 363797          Episode dated 18 May 1988        0     1988.0      \N
#
#        runtimeMinutes                      genres
# 0                  \N                 Drama,Short
# 1                  \N                Comedy,Short
# 2                  \N           Documentary,Short
# 3                  \N                       Short
# 4                   1                Comedy,Short
# ...               ...                         ...
# 363793              5                 Music,Short
# 363794             45  Action,Adventure,Animation
# 363795             \N                          \N
# 363796             96                 Documentary
# 363797             \N                          \N
#
# [363798 rows x 11 columns]

# %%
years = list(corrl_Data['startYear'].unique())
correlation_year = pd.DataFrame()
for year in years:
    X=corrl_Data[corrl_Data['startYear']==year].iloc[:,[1,2]]
    corr = X.corr()
    corr = corr['averageRating'][1]
    newRow = {'Correlation':corr,'Year':year}
    correlation_year = correlation_year.append(newRow, ignore_index=True)
correlation_year = correlation_year.reindex(columns=['Year', 'Correlation'])
correlation_year
# Out:
#       Year  Correlation
# 0   1900.0     0.215165
# 1   1901.0     0.215441
# 2   1904.0     0.237953
# 3   1903.0     0.172293
# 4   1902.0     0.198101
# ..     ...          ...
# 95  1999.0     0.029081
# 96  1998.0     0.022453
# 97  1994.0     0.034603
# 98  1997.0     0.021589
# 99  1996.0     0.008171
#
# [100 rows x 2 columns]

# %%
import matplotlib.pyplot
import pylab
matplotlib.pyplot.scatter(correlation_year['Year'],correlation_year['Correlation'])

# %%
plt.bar(np.arange(len(correlation_year['Year'])), correlation_year['Correlation'])
# Out:
# <BarContainer object of 100 artists>
