# %%
import pandas as pd
import os
import numpy as np
from itertools import combinations
from matplotlib import pyplot as plt
import pdfcrowd
from ipynb.fs.full.bse_Scrape import security_names
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [/Users/pemawangmo/.wdm/drivers/chromedriver/mac64/91.0.4472.101/chromedriver] found in cache

# %% [markdown]
# # identify the top 10 gainers (%) across groups over the 5 years period.
# # Note: The gain is the closing price on the last day of the period, divided by the closing price on the first day of the period, minus 1.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security      gain
# 139   504132  7.057637
# 106   511539  5.025157
# 82    514183  4.285132
# 74    504176  3.190584
# 117   500800  3.062201
# 63    500027  3.026806
# 76    504340  2.522727
# 125   500012  2.380471
# 20    500790  2.159933
# 133   500820  2.116577

# %% [markdown]
# # identify the top 10 gainers (%) across groups over the 3 years period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df = df[0:750]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security      gain
# 165   511539  5.025157
# 10    511549  3.658902
# 137   511571  2.624595
# 118   504340  2.522727
# 92    500034  2.037351
# 127   514183  1.955581
# 224   511601  1.545455
# 95    500027  1.467680
# 209   500820  1.404812
# 32    500790  1.327928

# %% [markdown]
# # identify the top 10 gainers (%) across groups over the 2 years period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df = df[0:500]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security      gain
# 172   511539  5.025157
# 131   514183  1.799353
# 195   500800  1.717421
# 101   500058  1.417910
# 142   511571  1.309278
# 9     517429  1.262162
# 153   508814  1.111137
# 110   521210  1.111111
# 119   504176  1.081438
# 136   508486  1.080473

# %% [markdown]
# # identify the top 10 gainers (%) across groups over the 1 year period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df = df[0:250]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security      gain
# 129   504340  7.611111
# 66    517467  5.974138
# 181   511539  5.025157
# 5     514175  3.939286
# 187   504180  3.626728
# 170   504220  3.159091
# 47    526638  2.924000
# 108   500058  2.375000
# 254   521222  2.166667
# 199   523519  1.960317

# %% [markdown]
# # identify the top 10 gainers (%) across groups over the 6 months period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df = df[0:130]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security      gain
# 130   504340  6.045455
# 29    523558  4.932692
# 205   523519  3.287356
# 47    526638  2.924000
# 249   524640  2.794643
# 218   511451  2.473333
# 215   517421  2.412628
# 60    500277  2.090909
# 43    500052  2.084364
# 109   500058  2.000000

# %% [markdown]
# # identify the top 10 gainers (%) across groups over the 3 months period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df = df[0:75]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security      gain
# 31    523558  5.232323
# 49    526638  2.924000
# 123   521210  2.492647
# 136   504340  2.369565
# 270   521222  2.053571
# 173   500306  1.916185
# 249   508664  1.589577
# 183   511618  1.538462
# 229   517399  1.507937
# 221   500013  1.503448

# %% [markdown]
# # identify the top 10 gainers (%) across groups over the 1 month period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df = df[0:30]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security      gain
# 50    526638  1.687671
# 274   511431  1.512241
# 227   500013  1.491991
# 176   500306  1.466993
# 10    517498  0.970655
# 169   521151  0.906383
# 167   500296  0.905983
# 22    500014  0.902174
# 266   511593  0.843243
# 39    523419  0.828125

# %% [markdown]
# # Draw a correlation matrix of any 30 stocks on the Sensex. This is a matrix with both axes holding the stock names. The colour of each cell is the correlation between that pair of stocks: blue for -1 and green for 1.

# %%
dfs = {}
stock_names = set()
def read_dfs():
    for root,dirs,files in os.walk(os.curdir):
        for file in files:
            if len(stock_names) == 30:
                return
            if file.endswith('.csv') and file.startswith("5"):
                name = os.path.splitext(file)[0]
                df = pd.read_csv(file,thousands=",")
                dfs[name] = df
                stock_names.add(name)
read_dfs()

# %%
samp = pd.DataFrame(columns=stock_names,index=stock_names)
for n1,n2 in combinations(stock_names,2):
    df1 = dfs[n1]
    df2 = dfs[n2]
    c1 = df1["Total Turnover (Rs.)"].corr(df2["Total Turnover (Rs.)"])
    c2 = df2["Total Turnover (Rs.)"].corr(df1["Total Turnover (Rs.)"])
    samp.loc[n1,n2] = c1
    samp.loc[n2,n1] = c2
    samp.loc[n1,n1] = 1
    samp.loc[n2,n2] = 1
samp = samp.astype({name:"float" for name in stock_names})

# %%
samp.style.background_gradient(cmap="brg")
# Out:
# <style  type="text/css" >
#     #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col0 {
#             background-color:  #00ff00;
#             color:  #000000;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col1 {
#             background-color:  #1e00e1;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col2 {
#             background-color:  #1c00e3;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col3 {
#             background-color:  #2c00d3;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col4 {
#             background-color:  #1a00e5;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col5 {
#             background-color:  #1000ef;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col6 {
#             background-color:  #1000ef;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col7 {
#             background-color:  #1400eb;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col8 {
#             background-color:  #2600d9;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col9 {
#             background-color:  #5e00a1;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col10 {
#             background-color:  #8a0075;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col11 {
#             background-color:  #2800d7;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col12 {
#             background-color:  #1600e9;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col13 {
#             background-color:  #1000ef;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col14 {
#             background-color:  #4a00b5;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col15 {
#             background-color:  #5c00a3;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col16 {
#             background-color:  #3800c7;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col17 {
#             background-color:  #1200ed;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col18 {
#             background-color:  #5400ab;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col19 {
#             background-color:  #3a00c5;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col20 {
#             background-color:  #5000af;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col21 {
#             background-color:  #1a00e5;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col22 {
#             background-color:  #2e00d1;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col23 {
#             background-color:  #4400bb;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col24 {
#             background-color:  #1a00e5;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col25 {
#             background-color:  #3a00c5;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col26 {
#             background-color:  #62009d;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col27 {
#             background-color:  #2800d7;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col28 {
#             background-color:  #2200dd;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow0_col29 {
#             background-color:  #2600d9;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col0 {
#             background-color:  #2600d9;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col1 {
#             background-color:  #00ff00;
#             color:  #000000;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col2 {
#             background-color:  #2600d9;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col3 {
#             background-color:  #3800c7;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col4 {
#             background-color:  #2800d7;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col5 {
#             background-color:  #2600d9;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col6 {
#             background-color:  #1800e7;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col7 {
#             background-color:  #1000ef;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col8 {
#             background-color:  #2600d9;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col9 {
#             background-color:  #3a00c5;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col10 {
#             background-color:  #3c00c3;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col11 {
#             background-color:  #1800e7;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col12 {
#             background-color:  #1800e7;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col13 {
#             background-color:  #1c00e3;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col14 {
#             background-color:  #2200dd;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col15 {
#             background-color:  #1a00e5;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col16 {
#             background-color:  #2e00d1;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col17 {
#             background-color:  #1600e9;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col18 {
#             background-color:  #3200cd;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col19 {
#             background-color:  #2c00d3;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col20 {
#             background-color:  #3c00c3;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col21 {
#             background-color:  #2800d7;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col22 {
#             background-color:  #2000df;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col23 {
#             background-color:  #4c00b3;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col24 {
#             background-color:  #0a00f5;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col25 {
#             background-color:  #1000ef;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col26 {
#             background-color:  #0c00f3;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col27 {
#             background-color:  #4c00b3;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col28 {
#             background-color:  #2200dd;
#             color:  #f1f1f1;
#         }    #T_9938a596_b7ac_11eb_9394_1fe0f241c89crow1_col29 {
#             background-color:  #

# %% [markdown]
# # Draw a sparkline showing the data 23,80,92,62,98,7,9,56,19,68.

# %%
import base64
import io


def spark_line(data, figsize=(4, 0.25), **kwags):
    data = list(data)

    fig, ax = plt.subplots(1, 1, figsize=figsize, **kwags)
    ax.plot(data)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_xticks([])
    ax.set_yticks([])

    plt.plot(len(data) - 1, data[len(data) - 1], 'r.')

    ax.fill_between(range(len(data)), data, len(data)*[min(data)], alpha=0.1)

    img = io.BytesIO()
    plt.savefig(img, transparent=True, bbox_inches='tight')
    img.seek(0)
    plt.close()

    return base64.b64encode(img.read()).decode("UTF-8")

# %%
values = [23,80,92,62,98,7,9,56,19,68]


with open("sparkline2.html", "a") as file:
        file.write('<div><h1>Sparkline to the given values</h1></div>')
        file.write('<br>')
        file.write('<br>')
        file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(values)))
        file.write('<div></div>')

# %% [markdown]
# # For each stock, draw a sparkline showing last month's closing price trend

# %%
closing_price_values = list()
for file in os.listdir():
    if file.endswith('.csv') and file.startswith("5"):
        filename = os.path.splitext(file)[0]
        if not filename.isdecimal() :
            continue
        df = pd.read_csv(file,thousands=",")
        try:
            closing_price_values.append(df["Close"][0:30].values)
        except Exception as e:
            closing_price_values.append(df["Close Price"][0:30].values)

with open("bse_closing_price3.html", "a") as file:
    file.write('<div><h1>Sparkline to the Closing Price values</h1></div>')
    file.write('<br>')
    file.write('<br>')
    for value in closing_price_values:
        file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

# %% [markdown]
# # Convert these files into PDF without using a browser

# %%
client = pdfcrowd.HtmlToPdfClient('demo', 'ce544b6ea52a5621fb9d55f8b542d14d')
client.convertFileToFile('bse_closing_price3.html', 'bse_closing_price3.pdf')
